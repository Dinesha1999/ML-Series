# %%
#To plot the data to findout insights ofthe data,pandas,matplotlib and seaborn are main librariea
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="white" , color_codes =True)

# %%
#read our data(iris)
iris = pd.read_csv("iris.csv")
iris.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## Scatter Plot

# %%
sns.FacetGrid(iris, hue ="species" ,height=6).map(plt.scatter,"petal_length","sepal_width").add_legend()

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# #### converting categorical variables into numbers

# %%
flower_mapping = {'setosa':0 , 'versicolor':1,'viginica':2}
iris["species"]= iris["species"].map(flower_mapping)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2      0.0
# 1           4.9          3.0           1.4          0.2      0.0
# 2           4.7          3.2           1.3          0.2      0.0
# 3           4.6          3.1           1.5          0.2      0.0
# 4           5.0          3.6           1.4          0.2      0.0

# %% [markdown]
# ### Preparing inputs and outputs

# %%
X = iris[['sepal_length','sepal_width','petal_length','petal_width']].values
y = iris[['species']].values
